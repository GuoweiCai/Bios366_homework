# %% [markdown]
# INSTRUCTOR COMMENTS BELOW IN ALL CAPS

# %% [markdown]
# ## Question 2
#
# Carlin (1992) considers a Bayesian approach to meta-analysis, and includes the following examples of 22 trials of beta-blockers to prevent mortality after myocardial infarction. These data are given below.
#
# In one possible random effects model we assume the true effect (on a log-odds scale) $d_i$ in a trial $i$
# is drawn from some population distribution. Let $r^C_i$ denote number of events in the control group in trial $i$, and $r^T_i$ denote events under active treatment in trial $i$. Our model is:
#
# $$\begin{aligned}
# r^C_i &\sim \text{Binomial}\left(p^C_i, n^C_i\right) \\
# r^T_i &\sim \text{Binomial}\left(p^T_i, n^T_i\right) \\
# \text{logit}\left(p^C_i\right) &= \mu_i \\
# \text{logit}\left(p^T_i\right) &= \mu_i + \delta \\
# \mu_i &\sim \text{Normal}(m, s).
# \end{aligned}$$
#
# In this case, we want to make inferences about the population effect $m$, and the predictive distribution for the effect $\delta_{\text{new}}$ in a new trial.
#
# This particular model uses a random effect for the population mean, and a fixed effect for the treatment effect. There are 3 other models you could fit to represent all possible combinations of fixed or random effects for these two parameters.
#
# Build all 4 models to estimate the treatment effect in PyMC and
#
# 1. use convergence diagnostics to check for convergence in each model
# 2. use posterior predictive checks to compare the fit of the models
# 3. use DIC to compare the models as approximations of the true generating model
#
# Which model would you select and why?

# %%
import pymc as pm
import numpy as np

# %%
r_t_obs = [3, 7, 5, 102, 28, 4, 98, 60, 25, 138, 64, 45, 9, 57, 25, 33, 28, 8, 6, 32, 27, 22]
n_t_obs = [38, 114, 69, 1533, 355, 59, 945, 632, 278,1916, 873, 263, 291, 858, 154, 207, 251, 151, 174, 209, 391, 680]
r_c_obs = [3, 14, 11, 127, 27, 6, 152, 48, 37, 188, 52, 47, 16, 45, 31, 38, 12, 6, 3, 40, 43, 39]
n_c_obs = [39, 116, 93, 1520, 365, 52, 939, 471, 282, 1921, 583, 266, 293, 883, 147, 213, 122, 154, 134, 218, 364, 674]
N = len(n_c_obs)

# %% [markdown]
# **Model 1. Random mean, fixed treatment effect**

# %%
mu = pm.Normal('mu', .5, 16)
delta_T = pm.Normal('delta_T', 0, 4)

def logit(p):
    return np.log(p) - np.log(1 - p)

def inv_logit(p):
    return np.exp(p) / (1 + np.exp(p))

@pm.deterministic(plot=False)
def p_i(m=mu,d=delta_T):
    ''' Concatenate Poisson means '''
    pi_t = np.empty(len(r_t_obs))
    pi_t[::] = inv_logit(m+d)
    pi_c = np.empty(len(r_c_obs))
    pi_c[::] = inv_logit(m)
    return [pi_t,pi_c]

[ri_t,ri_c] = pm.Binomial('ri_t', n=[n_t_obs,n_c_obs],p=p_i, 
                       value=[r_t_obs,r_c_obs], 
                       observed=True)

M=pm.MCMC([mu, delta_T, p_i, ri_t])

M.sample(iter=10000, burn=1000)

from pymc.Matplot import plot
plot(M)
# Out:
#  [--                5%                  ] 532 of 10000 complete in 0.5 sec
#  [----             10%                  ] 1075 of 10000 complete in 1.0 sec
#  [-----            15%                  ] 1531 of 10000 complete in 1.5 sec
#  [-------          19%                  ] 1986 of 10000 complete in 2.0 sec
#  [---------        24%                  ] 2440 of 10000 complete in 2.5 sec
#  [-----------      28%                  ] 2897 of 10000 complete in 3.0 sec
#  [------------     33%                  ] 3355 of 10000 complete in 3.5 sec
#  [--------------   38%                  ] 3815 of 10000 complete in 4.0 sec
#  [---------------- 42%                  ] 4276 of 10000 complete in 4.5 sec
#  [-----------------47%                  ] 4737 of 10000 complete in 5.0 sec
#  [-----------------51%                  ] 5198 of 10000 complete in 5.5 sec
#  [-----------------56%-                 ] 5659 of 10000 complete in 6.0 sec
#  [-----------------61%---               ] 6120 of 10000 complete in 6.5 sec
#  [-----------------65%-----             ] 6584 of 10000 complete in 7.0 sec
#  [-----------------70%------            ] 7043 of 10000 complete in 7.5 sec
#  [-----------------75%--------          ] 7506 of 10000 complete in 8.0 sec
#  [-----------------79%----------        ] 7968 of 10000 complete in 8.5 sec
#  [-----------------84%------------      ] 8432 of 10000 complete in 9.0 sec
#  [-----------------88%-------------     ] 8895 of 10000 complete in 9.5 sec
#  [-----------------93%---------------   ] 9361 of 10000 complete in 10.0 sec
#  [-----------------98%----------------- ] 9827 of 10000 complete in 10.5 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 10.7 sec
# Plotting delta_T
# Plotting
#  mu

# %% [markdown]
# **Model 2. Fixed mean, random treatment effect**

# %% [markdown]
# THIS IS NOT QUITE CORRET. FOR YOUR TREATMENT EFFECT TO BE A RANDOM EFFECT IT NEEDS TO HAVE ITS OWN DISTRIBUTION, NOT JUST A PRIOR. SO THE MEAN AND VARIANCE OF `delta_C` SHOULD HAVE PRIORS OF THEIR OWN.

# %%
mu = pm.Normal('mu', .5, 16)
delta_C = pm.Normal('delta_C', 0, 16)

@pm.deterministic(plot=False)
def p_i(m=mu,d=delta_C):
    ''' Concatenate Poisson means '''
    pi_t = np.empty(len(r_t_obs))
    pi_t[::] = inv_logit(m)
    pi_c = np.empty(len(r_c_obs))
    pi_c[::] = inv_logit(m+d)
    return [pi_t,pi_c]

[ri_t,ri_c] = pm.Binomial('ri_t', n=[n_t_obs,n_c_obs],p=p_i, 
                       value=[r_t_obs,r_c_obs], 
                       observed=True)

M=pm.MCMC([mu, delta_C, p_i, ri_t])
M.sample(iter=10000, burn=1000)

from pymc.Matplot import plot
plot(M)
# Out:
#  [--                5%                  ] 551 of 10000 complete in 0.5 sec
#  [----             11%                  ] 1101 of 10000 complete in 1.0 sec
#  [-----            15%                  ] 1558 of 10000 complete in 1.5 sec
#  [-------          20%                  ] 2015 of 10000 complete in 2.0 sec
#  [---------        24%                  ] 2453 of 10000 complete in 2.5 sec
#  [-----------      28%                  ] 2897 of 10000 complete in 3.0 sec
#  [------------     33%                  ] 3354 of 10000 complete in 3.5 sec
#  [--------------   38%                  ] 3810 of 10000 complete in 4.0 sec
#  [---------------- 42%                  ] 4266 of 10000 complete in 4.5 sec
#  [-----------------46%                  ] 4697 of 10000 complete in 5.0 sec
#  [-----------------51%                  ] 5155 of 10000 complete in 5.5 sec
#  [-----------------56%-                 ] 5605 of 10000 complete in 6.0 sec
#  [-----------------60%---               ] 6064 of 10000 complete in 6.5 sec
#  [-----------------65%----              ] 6525 of 10000 complete in 7.0 sec
#  [-----------------69%------            ] 6986 of 10000 complete in 7.5 sec
#  [-----------------74%--------          ] 7437 of 10000 complete in 8.0 sec
#  [-----------------78%----------        ] 7896 of 10000 complete in 8.5 sec
#  [-----------------83%-----------       ] 8357 of 10000 complete in 9.0 sec
#  [-----------------88%-------------     ] 8801 of 10000 complete in 9.5 sec
#  [-----------------92%---------------   ] 9248 of 10000 complete in 10.0 sec
#  [-----------------97%----------------  ] 9708 of 10000 complete in 10.5 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 10.8 sec
# Plotting mu
# Plotting
#  delta_C

# %% [markdown]
# **Model 3. Random mean, random treatment effect**

# %%
Delta_c = pm.Normal('Delta_c', 0, 4)
Delta_t = pm.Normal('Delta_t', 0, 4)
mu = pm.Normal('mu',0.5,16)

@pm.deterministic(plot=False)
def p_i(d_t=Delta_t,d_c=Delta_c,m=mu):
    ''' Concatenate Poisson means '''
    pi_t = np.empty(len(r_t_obs))
    pi_t[::] = inv_logit(m+d_t)
    pi_c = np.empty(len(r_c_obs))
    pi_c[::] = inv_logit(m+d_c)
    return [pi_t,pi_c]

[ri_t,ri_c] = pm.Binomial('ri_t', n=[n_t_obs,n_c_obs],p=p_i, 
                       value=[r_t_obs,r_c_obs], 
                       observed=True)

M=pm.MCMC([mu, Delta_c, Delta_t, ri_t])
M.sample(iter=10000, burn=1000)

from pymc.Matplot import plot
plot(M)
# Out:
#  [-                 3%                  ] 358 of 10000 complete in 0.5 sec
#  [--                7%                  ] 734 of 10000 complete in 1.0 sec
#  [----             10%                  ] 1069 of 10000 complete in 1.5 sec
#  [-----            13%                  ] 1392 of 10000 complete in 2.0 sec
#  [------           17%                  ] 1719 of 10000 complete in 2.5 sec
#  [-------          20%                  ] 2057 of 10000 complete in 3.0 sec
#  [---------        24%                  ] 2404 of 10000 complete in 3.5 sec
#  [----------       27%                  ] 2748 of 10000 complete in 4.0 sec
#  [-----------      30%                  ] 3076 of 10000 complete in 4.5 sec
#  [------------     34%                  ] 3401 of 10000 complete in 5.0 sec
#  [--------------   37%                  ] 3737 of 10000 complete in 5.5 sec
#  [---------------  40%                  ] 4061 of 10000 complete in 6.0 sec
#  [---------------- 43%                  ] 4367 of 10000 complete in 6.5 sec
#  [-----------------46%                  ] 4696 of 10000 complete in 7.0 sec
#  [-----------------50%                  ] 5014 of 10000 complete in 7.5 sec
#  [-----------------53%                  ] 5354 of 10000 complete in 8.0 sec
#  [-----------------56%-                 ] 5695 of 10000 complete in 8.5 sec
#  [-----------------60%--                ] 6040 of 10000 complete in 9.0 sec
#  [-----------------63%----              ] 6366 of 10000 complete in 9.5 sec
#  [-----------------66%-----             ] 6691 of 10000 complete in 10.0 sec
#  [-----------------70%------            ] 7033 of 10000 complete in 10.5 sec
#  [-----------------73%-------           ] 7352 of 10000 complete in 11.0 sec
#  [-----------------76%---------         ] 7692 of 10000 complete in 11.5 sec
#  [-----------------80%----------        ] 8037 of 10000 complete in 12.0 sec
#  [-----------------83%-----------       ] 8376 of 10000 complete in 12.5 sec
#  [-----------------87%-------------     ] 8722 of 10000 complete in 13.0 sec
#  [-----------------90%--------------    ] 9060 of 10000 complete in 13.5 sec
#  [-----------------93%---------------   ] 9386 of 10000 complete in 14.0 sec
#  [-----------------97%----------------  ] 9726 of 10000 complete in 14.5 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 14.9 sec
# Plotting Delta_c
# Plotting
#  mu
# Plotting
#  Delta_t

# %% [markdown]
# **Model 4. Fixed mean, fixed treatment effect**

# %% [markdown]
# THIS IS A DIFFERENT PARAMETERIZATION THAT WAS SPECIFIED BY THE PROBLEM. THE CONTROL MEAN SHOULD BE:
#
# $\mu$
#
# AND THE TREATMENT MEAN SHOULD BE
#
# $\mu + \delta$

# %%
mu_c = pm.Normal('mu_c', .5, 16)
mu_t = pm.Normal('mu_t', .5, 16)

@pm.deterministic(plot=False)
def p_i(m_c=mu_c,m_t = mu_t):
    ''' Concatenate Poisson means '''
    pi_t = np.empty(len(r_t_obs))
    pi_t[::] = inv_logit(m_t)
    pi_c = np.empty(len(r_c_obs))
    pi_c[::] = inv_logit(m_c)
    return [pi_t,pi_c]

[ri_t,ri_c] = pm.Binomial('ri_t', n=[n_t_obs,n_c_obs],p=p_i, 
                       value=[r_t_obs,r_c_obs], 
                       observed=True)

M=pm.MCMC([mu_c, mu_t, p_i, ri_t])
M.sample(iter=10000, burn=1000)

from pymc.Matplot import plot
plot(M)
# Out:
#  [--                5%                  ] 577 of 10000 complete in 0.5 sec
#  [----             11%                  ] 1129 of 10000 complete in 1.0 sec
#  [------           15%                  ] 1591 of 10000 complete in 1.5 sec
#  [-------          20%                  ] 2025 of 10000 complete in 2.0 sec
#  [---------        24%                  ] 2465 of 10000 complete in 2.5 sec
#  [-----------      29%                  ] 2926 of 10000 complete in 3.0 sec
#  [------------     33%                  ] 3335 of 10000 complete in 3.5 sec
#  [--------------   37%                  ] 3732 of 10000 complete in 4.0 sec
#  [---------------  41%                  ] 4194 of 10000 complete in 4.5 sec
#  [-----------------46%                  ] 4626 of 10000 complete in 5.0 sec
#  [-----------------50%                  ] 5096 of 10000 complete in 5.5 sec
#  [-----------------55%-                 ] 5554 of 10000 complete in 6.0 sec
#  [-----------------60%--                ] 6006 of 10000 complete in 6.5 sec
#  [-----------------64%----              ] 6472 of 10000 complete in 7.0 sec
#  [-----------------68%------            ] 6884 of 10000 complete in 7.5 sec
#  [-----------------73%-------           ] 7347 of 10000 complete in 8.0 sec
#  [-----------------77%---------         ] 7796 of 10000 complete in 8.5 sec
#  [-----------------82%-----------       ] 8263 of 10000 complete in 9.0 sec
#  [-----------------87%-------------     ] 8731 of 10000 complete in 9.5 sec
#  [-----------------92%--------------    ] 9203 of 10000 complete in 10.0 sec
#  [-----------------96%----------------  ] 9674 of 10000 complete in 10.5 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 10.9 sec
# Plotting mu_t
# Plotting
#  mu_c

# %% [markdown]
# SCORE: 18/25
